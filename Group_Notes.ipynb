# %% [markdown]
# ![](Data_Science_VD.png)
#
#
# # CB Data Science
# ## Group Notes & Collaborative Code
#
# &nbsp;
#
# ###  General Notes
#
# *  This is a quick test of a notebook run through [**TheLittlestJupyterHub**](https://tljh.jupyter.org/en/latest/index.html).  It is hosted at DigitalOcean.
# *  This is also a test of _**markdown**_ -- to see how the various options render in this browser on this host.
# *  Finally, our hope is to have this be a collaborative place to take/keep notes, and explore code snippetts and graphs for our study group!
#
#
# ###  Resources
#
# *  [**Python Data Science Handbook on GitHub**](https://github.com/jakevdp/PythonDataScienceHandbook)
# *  [**Markdown Cheat Sheet**](https://www.ibm.com/support/knowledgecenter/en/SSGNPV_1.1.3/dsx/markd-jupyter.html)
# *  [**Jupyter Docs**](https://jupyter.org/)
# *  [**Numpy Docs**](https://numpy.org/)
# *  [**Matplotlib Docs**](https://matplotlib.org/)
# *  [**Pandas Docs**](https://pandas.pydata.org/)
# *  [**Python 3.7 Docs**](https://docs.python.org/3/)
#
# ###  Quick Graphing Test

# %%
import matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

years = [1983, 1984, 1985, 1986, 1987]
total_populations = [8939007, 8954518, 8960387, 8956741, 8943721]

plt.plot(years, total_populations)
plt.title("Year vs Population in Bulgaria")
plt.xlabel("Year")
plt.ylabel("Total Population")
plt.show()

# %% [markdown]
# ### Chapter 1:  IPython:  Beyond "Normal" Python

# %% [markdown]
# # Hello World (cliche, I know)
